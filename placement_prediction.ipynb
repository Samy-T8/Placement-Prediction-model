# %%
import numpy as np
import pandas as pd

# %%
ds = pd.read_csv("/placement.csv")

# %%
ds
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
ds = ds.iloc[: , 1:]

# %%
ds
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]

# %%
ds_test = ds.iloc[0:91 , :]

# %%
ds_test
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 86   5.1  128.0          0
# 87   5.7  132.0          1
# 88   4.4  149.0          0
# 89   4.9  151.0          0
# 90   7.3   86.0          1
#
# [91 rows x 3 columns]

# %%
ds_test = ds.iloc[0:90 , :]

# %%
ds_test
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 85   5.8  166.0          1
# 86   5.1  128.0          0
# 87   5.7  132.0          1
# 88   4.4  149.0          0
# 89   4.9  151.0          0
#
# [90 rows x 3 columns]

# %%
ds_train = ds_test

# %%
ds_train
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 85   5.8  166.0          1
# 86   5.1  128.0          0
# 87   5.7  132.0          1
# 88   4.4  149.0          0
# 89   4.9  151.0          0
#
# [90 rows x 3 columns]

# %%
ds_test = ds.iloc[90 : , :
                  ]

# %%
ds_test
# Out:
#     cgpa     iq  placement
# 90   7.3   86.0          1
# 91   7.5  158.0          1
# 92   5.2  110.0          0
# 93   6.8  112.0          1
# 94   4.7   52.0          0
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1

# %%
ds_test.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4293090281.py in <cell line: 0>()
# ----> 1 ds_test.shape()
#
# TypeError: 'tuple' object is not callable

# %%
ds_test.shape
# Out:
# (10, 3)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(ds['cgpa'] , ds['iq'] , c = ds['placement'])

# %%
from sklearn.model_selection import train_test_split

# %%
X = ds.iloc[: , 0:2]
Y = ds.iloc[: , -1]

Y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
X_train , X_test , Y_train , Y_test = train_test_split(X , Y , test_size=0.1);

# %%
x_train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1710797709.py in <cell line: 0>()
# ----> 1 x_train
#
# NameError: name 'x_train' is not defined

# %%
X_train
# Out:
#     cgpa     iq
# 11   6.9  138.0
# 84   5.7  169.0
# 4    5.8  142.0
# 55   7.8  114.0
# 72   7.3  116.0
# ..   ...    ...
# 45   6.0   66.0
# 16   5.2  224.0
# 75   4.8  169.0
# 2    5.3  121.0
# 32   7.0  139.0
#
# [90 rows x 2 columns]

# %%
X_test
# Out:
#     cgpa     iq
# 76   4.9  155.0
# 85   5.8  166.0
# 14   6.1  103.0
# 30   7.6  128.0
# 38   6.5  160.0
# 43   6.8  141.0
# 44   7.5   61.0
# 49   5.4  135.0
# 74   6.7  154.0
# 63   6.3  128.0

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 0.81808444,  0.38167132],
#        [-0.21528538,  1.14610994],
#        [-0.12917123,  0.48030857],
#        [ 1.59311179, -0.21015212],
#        [ 1.16254104, -0.1608335 ],
#        [ 0.21528538, -0.23481143],
#        [ 1.16254104, -0.90061281],
#        [ 0.90419859, -1.44311764],
#        [ 0.04305708,  0.65292374],
#        [-0.55974198, -0.21015212],
#        [ 0.38751368, -0.1608335 ],
#        [ 0.12917123,  0.23371546],
#        [-2.282025  ,  1.49134029],
#        [-0.81808444, -0.11151488],
#        [ 0.73197028,  0.01178167],
#        [ 0.04305708, -0.50606385],
#        [ 0.04305708,  0.03644098],
#        [ 1.24865519,  0.23371546],
#        [-0.47362783, -0.21015212],
#        [ 0.04305708, -1.91164453],
#        [ 0.55974198, -0.06219626],
#        [ 0.90419859, -0.25947074],
#        [ 0.12917123, -1.41845833],
#        [-0.47362783,  0.40633064],
#        [-1.07642689, -1.73902936],
#        [ 1.42088349, -0.82663488],
#        [ 0.38751368,  0.45564926],
#        [ 0.47362783, -0.80197557],
#        [ 0.73197028, -0.25947074],
#        [-0.64585613,  0.94883546],
#        [-0.99031274, -0.25947074],
#        [ 1.33476934,  0.87485753],
#        [ 0.81808444,  0.40633064],
#        [-0.21528538,  0.50496788],
#        [-0.73197028,  0.13507822],
#        [-0.47362783, -0.38276729],
#        [-0.90419859,  0.70224236],
#        [-1.7653401 , -0.33344867],
#        [-0.81808444, -1.46777695],
#        [-2.1097967 ,  2.7243058 ],
#        [-0.90419859,  1.81191132],
#        [-1.33476934,  0.65292374],
#        [-0.81808444, -0.77731626],
#        [-0.64585613, -0.30878936],
#        [-0.99031274,  0.99815408],
#        [ 1.16254104, -1.78834798],
#        [-0.90419859, -0.06219626],
#        [-1.67922595, -1.17186522],
#        [ 2.02368255,  1.12145063],
#        [ 0.30139953, -0.48140454],
#        [-0.73197028,  1.31872512],
#        [ 0.99031274, -1.8376666 ],
#        [-0.73197028, -1.39379902],
#        [-0.90419859, -1.51709557],
#        [-0.99031274,  0.45564926],
#        [-0.90419859,  0.28303408],
#        [ 1.7653401 , -1.07322798],
#        [ 1.85145425,  0.65292374],
#        [ 0.47362783, -2.10891902],
#        [ 0.90419859,  1.29406581],
#        [-0.64585613,  0.23371546],
#        [ 0.99031274,  0.70224236],
#        [-1.67922595, -0.55538247],
#        [ 0.90419859,  1.88588925],
#        [-0.04305708, -0.4074266 ],
#        [ 1.16254104,  0.35701201],
#        [ 0.47362783,  0.18439684],
#        [ 0.30139953,  0.11041891],
#        [-1.07642689, -0.03753695],
#        [-1.42088349,  1.91054856],
#        [ 0.64585613,  1.46668098],
#        [-0.21528538,  0.43098995],
#        [-1.16254104,  0.57894581],
#        [-1.07642689, -0.8759535 ],
#        [ 0.12917123,  0.82553891],
#        [ 0.12917123, -1.02390936],
#        [ 0.81808444, -0.65401971],
#        [ 2.19591085, -0.06219626],
#        [ 1.33476934,  0.18439684],
#        [-1.33476934, -1.98562246],
#        [ 0.55974198,  0.38167132],
#        [-0.21528538,  0.23371546],
#        [-0.64585613, -0.80197557],
#        [ 0.73197028, -0.80197557],
#        [ 1.85145425,  1.07213201],
#        [ 0.04305708, -1.39379902],
#        [-0.64585613,  2.50237201],
#        [-0.99031274,  1.14610994],
#        [-0.55974198, -0.03753695],
#        [ 0.90419859,  0.40633064]])

# %%
X_test = scaler.fit_transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
model = clf.fit(X_train , Y_train)

# %%
model
# Out:
# LogisticRegression()

# %%
Y_pred = clf.predict(X_test)

# %%
Y_test
# Out:
# 76    0
# 85    1
# 14    0
# 30    1
# 38    1
# 43    1
# 44    1
# 49    0
# 74    1
# 63    1
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(Y_test , Y_pred)
# Out:
# 0.8

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X_train, Y_train.values, clf=clf, legend=5)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf , open("model.pkl" , "wb"))
